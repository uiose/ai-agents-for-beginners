# %% [markdown]
# # ਪਾਠ 12 - ਏਜੰਟ ਸਕ੍ਰੈਚਪੈਡ ਨਾਲ ਗੱਲਬਾਤ ਇਤਿਹਾਸ ਘਟਾਉਣਾ
#
# ਇਹ ਨੋਟਬੁੱਕ ਮਾਈਕ੍ਰੋਸਾਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਲੰਮੇ ਗੱਲਬਾਤ ਵਿੱਚ ਸੰਦਰਭ ਨੂੰ ਕਿਵੇਂ ਸੰਭਾਲਣਾ ਹੈ, ਇਹ ਦਿਖਾਉਂਦਾ ਹੈ। ਜਿਵੇਂ ਜਿਵੇਂ ਗੱਲਬਾਤ ਵੱਧਦੀ ਹੈ, ਟੋਕੇਨ ਗਿਣਤੀ ਵੱਧ ਜਾਂਦੀ ਹੈ — ਆਖਿਰਕਾਰ ਮਾਡਲ ਦੇ ਸੰਦਰਭ ਵਿੰਡੋ ਤੋਂ ਬਾਹਰ ਚਲੇ ਜਾਂਦੇ ਹਨ। ਅਸੀਂ ਇਸ ਨੂੰ **ਸੰਦਰਭ ਸਾਰਾਂਸ਼ ਪੈਟਰਨ** ਅਤੇ **ਏਜੰਟ ਸਕ੍ਰੈਚਪੈਡ** ਨਾਲ ਪੱਕੀ ਯਾਦ ਸ਼ਕਤੀ ਲਈ ਹੱਲ ਕਰਦੇ ਹਾਂ।
#
# ## ਤੁਸੀਂ ਜੋ ਸਿੱਖੋਗੇ:
# 1. **ਸੰਦਰਭ ਪ੍ਰਬੰਧਨ ਕਿਉਂ ਮਹੱਤਵਪੂਰਨ ਹੈ**: ਟੋਕੇਨ ਸੀਮਾਵਾਂ ਅਤੇ ਸੰਦਰਭ ਵਿੰਡੋਆਂ ਨੂੰ ਸਮਝਣਾ
# 2. **ਸੰਦਰਭ-ਜਾਣਕਾਰ ਏਜੰਟ**: ਉਹ ਏਜੰਟ ਬਣਾਓ ਜੋ ਆਪਣਾ ਗੱਲਬਾਤ ਸੰਦਰਭ ਖੁਦ ਸੰਭਾਲਦੇ ਹਨ
# 3. **ਸੰਦਰਭ ਸਾਰਾਂਸ਼ ਪੈਟਰਨ**: ਗੱਲਬਾਤ ਇਤਿਹਾਸ ਨੂੰ ਸੰਘਣਾ ਕਰਨ ਲਈ ਇਹਨਾਂ ਟੂਲਾਂ ਦੀ ਵਰਤੋਂ
# 4. **ਏਜੰਟ ਸਕ੍ਰੈਚਪੈਡ**: ਪੱਕੀ ਯਾਦ, ਜੋ ਸੰਦਰਭ ਘਟਾਉਣ ਤੋਂ ਬਾਅਦ ਵੀ ਸੱਚੀ ਰਹਿੰਦੀ ਹੈ
#
# ## ਜ਼ਰੂਰੀ ਤਿਆਰੀ:
# - ਐਜੁਰ OpenAI ਸੈਟਅੱਪ ਜਿਸ ਵਿੱਚ ਵਾਤਾਵਰਣ ਵੇਰੀਏਬਲ ਸੈੱਟ ਕੀਤੇ ਹੋਣ
# - ਪਿਛਲੇ ਪਾਠਾਂ ਤੋਂ ਬੇਸਿਕ ਏਜੰਟ ਸੰਕਲਪਾਂ ਦੀ ਸਮਝ

# %% [markdown]
# ## ਸੈਟਅੱਪ

# %%
# %pip install agent-framework azure-ai-projects azure-identity --quiet

# %%
import os
import asyncio
from datetime import datetime
from pathlib import Path

from dotenv import load_dotenv

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
# Load environment variables and create Azure AI Foundry provider
load_dotenv()

provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

print("✅ Azure AI Foundry provider configured")

# %% [markdown]
# ## ਸੰਦੇਭ ਪ੍ਰਬੰਧਨ ਕਿਉਂ ਜਰੂਰੀ ਹੈ
#
# ਹਰ ਇੱਕ LLM ਦਾ ਇੱਕ ਸੀਮਿਤ **ਸੰਦੇਭ ਵਿੰਡੋ** ਹੁੰਦਾ ਹੈ — ਜਿੰਨਾ ਵੱਧ ਤੋਂ ਵੱਧ ਟੋਕਨ ਉਹ ਇੱਕ ਵਾਰੀ ਵਿੱਚ ਪ੍ਰਕਿਰਿਆ ਕਰ ਸਕਦਾ ਹੈ। ਜਿਵੇਂ-ਜਿਵੇਂ ਬਹੁ-ਚਰਚਾ ਅੱਗੇ ਵੱਧਦੀ ਹੈ:
#
# - **ਟੋਕਨ ਗਿਣਤੀ ਰੇਖਾਕਾਰ ਤੌਰ ਤੇ ਵੱਧਦੀ ਹੈ** ਹਰ ਇੱਕ ਉਪਭੋਗਤਾ ਸੁਨੇਹੇ ਅਤੇ ਸਹਾਇਕ ਉੱਤਰ ਨਾਲ।
# - **ਪ੍ਰਾਂਪਟ ਟੋਕਨ ਲਾਗਤ 'ਤੇ ਹਕਮਤ ਕਰਦੇ ਹਨ** ਕਿਉਂਕਿ ਪੂਰਾ ਇਤਿਹਾਸ ਹਰ ਵਾਰੀ ਦੁਬਾਰਾ ਭੇਜਿਆ ਜਾਂਦਾ ਹੈ।
# - ਆਖ਼ਿਰਕਾਰ ਗੱਲਬਾਤ **ਸੰਦੇਭ ਵਿੰਡੋ ਤੋਂ ਵੱਧ ਜਾਂਦੀ ਹੈ** ਅਤੇ ਮਾਡਲ ਜਾਂ ਤਾਂ ਕਟਾਊ ਕਰਦਾ ਹੈ ਜਾਂ ਗਲਤੀ ਕਰਦਾ ਹੈ।
#
# ### ਸੰਦੇਭ ਪ੍ਰਬੰਧਨ ਲਈ ਹੇਠਾਂ ਦਿੱਤੀਆਂ ਰਣਨੀਤੀਆਂ
#
# | ਰਣਨੀਤੀ | ਇਹ ਕਿਵੇਂ ਕੰਮ ਕਰਦੀ ਹੈ | ਤਟस्थਾ |
# |---|---|---|
# | **ਕਟਾਊ** | ਸਭ ਤੋਂ ਪੁਰਾਣੇ ਸੁਨੇਹੇ ਹਟਾਓ | ਸ਼ੁਰੂਆਤੀ ਸੰਦਰਭ ਖੋ ਜਾਂਦਾ ਹੈ |
# | **ਸਾਰਾਂਸ਼ ਬਣਾਉਣਾ** | ਪੁਰਾਣੇ ਸੁਨੇਹਿਆਂ ਨੂੰ ਸਾਰ ਵਿੱਚ ਸੰਗ੍ਰਹਿਤ ਕਰੋ | ਕੁਝ ਵੇਰਵਾ ਖੋ ਜਾਂਦਾ ਹੈ, ਪਰ ਮੁੱਖ ਬਿੰਦੂ ਬਚ ਜਾਂਦੇ ਹਨ |
# | ** ਸਕ੍ਰੈਚਪੈਡ / ਬਾਹਰੀ ਯਾਦਦਾਸ਼ਤ** | ਗੱਲਬਾਤ ਤੋਂ ਬਾਹਰ ਮੁੱਖ ਤੱਥ ਸਟੋਰ ਕਰੋ | ਟੂਲ ਕਾਲਾਂ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ, ਪਰ ਕਿਸੇ ਵੀ ਕਟਾਊ ਤੋਂ ਬਾਅਦ ਜੀਵਿਤ ਰਹਿੰਦਾ ਹੈ |
#
# ਇਸ ਨੋਟਬੁੱਕ ਵਿੱਚ ਅਸੀਂ **ਸਾਰਾਂਸ਼ ਬਣਾਉਣਾ** ਅਤੇ ** ਸਕ੍ਰੈਚਪੈਡ ਟੂਲ** ਨੂੰ ਜੋੜਕੇ ਇਸ ਤਰ੍ਹਾਂ ਏਜੰਟ ਨੂੰ ਲਗਾਤਾਰਤਾ ਬਣਾਈ ਰੱਖਣ ਵਿੱਚ ਸਹਾਇਤਾ ਦਿੰਦੇ ਹਾਂ ਭਾਵੇਂ ਗੱਲਬਾਤ ਦਾ ਇਤਿਹਾਸ ਸੰਕੁਚਿਤ ਹੋ ਜਾਵੇ।

# %% [markdown]
# ## ਇੱਕ ਸੰਦਰਭ-ਸੁਝਾਵ ਵਾਲਾ ਏਜੰਟ ਬਣਾਉਣਾ

# %%
agent = await provider.create_agent(
    name="ContextAwareAgent",
    instructions="""You are a helpful travel planning assistant with excellent memory management.
When conversations get long:
1. Summarize previous context into key points
2. Track user preferences mentioned earlier
3. Reference previous decisions without repeating full details
Always maintain continuity while being concise.""",
)

print("🤖 Context-aware travel planning agent created")

# %% [markdown]
# ## ਲੰਮੀ ਗੱਲਬਾਤ ਦਾ ਅਨੁਕਰਨ
#
# ਆਓ ਇੱਕ ਬਹੁ-ਚਰਨ ਗੱਲਬਾਤ ਵਿੱਚੋਂGu ਦੌੜਾਂ, ਤਾਂ ਜੋ ਵੇਖ ਸਕੀਏ ਕਿ ਸੰਦਰਭ ਕਿਵੇਂ ਇਕੱਠਾ ਹੁੰਦਾ ਹੈ। ਏਜੰਟ ਨੂੰ ਚਾਬੀ ਜਾਣਕਾਰੀਆਂ (ਪਸੰਦ, ਬਜਟ, ਯਾਤਰਾ ਦੀਆਂ ਤਰੀਖਾਂ) ਪ੍ਰਤੀਚਰਨਾਂ ਵਿੱਚ ਸੰਭਾਲ ਕੇ ਰੱਖਣੀਆਂ ਚਾਹੀਦੀਆਂ ਹਨ ਅਤੇ ਲਗਾਤਾਰਤਾ ਦਿਖਾਉਣੀ ਚਾਹੀਦੀ ਹੈ।

# %%
session = agent.create_session()

# Turn 1 - Initial preferences
response = await agent.run("I'm planning a trip to Japan. I love sushi, temples, and photography.", session=session)
print(f"Turn 1: {response}\n")

# Turn 2 - More details
response = await agent.run("My budget is $3000 and I'll be traveling solo for 10 days in April.", session=session)
print(f"Turn 2: {response}\n")

# Turn 3 - Test context retention
response = await agent.run("Based on everything I've told you so far, what's the one thing you'd recommend I not miss?", session=session)
print(f"Turn 3: {response}\n")

# %% [markdown]
# ਧਿਆਨ ਦਿਓ ਕਿ ਏਜੰਟ ਪਿਛਲੇ ਚਰਣਾਂ ਤੋਂ ਸੰਦਰਭ ਕਿਵੇਂ ਬਰਕਰਾਰ ਰੱਖਦਾ ਹੈ — ਇਸਨੂੰ ਜਪਾਨ, ਸੁਸ਼ੀ, ਮੰਦਿਰ, ਫੋਟੋgraphy, $3000 ਬਜਟ, ਇਕੱਲਾ ਸਫਰ, ਅਤੇ ਅਪ੍ਰੈਲ ਸਮੇਂ ਬਾਰੇ ਪਤਾ ਹੈ। ਇਕ ਛੋਟੀ ਗੱਲਬਾਤ ਵਿੱਚ ਇਹ ਚੰਗਾ ਕੰਮ ਕਰਦਾ ਹੈ, ਪਰ ਜਿਵੇਂ ਗੱਲਬਾਤ ਵੱਧਦੀ ਹੈ, ਪੂਰਾ ਇਤਿਹਾਸ ਵਾਪਸ ਭੇਜਣਾ ਮਹਿੰਗਾ ਹੋ ਜਾਂਦਾ ਹੈ।
#
# ਆਓ ਵੱਧ ਚਰਣਾਂ ਨਾਲ ਗੱਲਬਾਤ ਜਾਰੀ ਰੱਖੀਏ ਤਾਂ ਕਿ ਸੰਦਰਭ ਦੀ ਸੰਗ੍ਰਹਿ ਨੂੰ ਵੇਖਿਆ ਜਾ ਸਕੇ:

# %%
# Turn 4 - Expand the conversation
response = await agent.run("What about accommodation? I prefer traditional Japanese inns.", session=session)
print(f"Turn 4: {response}\n")

# Turn 5 - Change of plans
response = await agent.run("Actually, I've changed my mind about the dates. I'll go in October instead for the autumn colors.", session=session)
print(f"Turn 5: {response}\n")

# Turn 6 - Test retention after change
response = await agent.run("Summarize my complete travel plan so far — destination, budget, duration, interests, accommodation, and timing.", session=session)
print(f"Turn 6: {response}\n")

# %% [markdown]
# ## ਸੰਦੇਸ਼ ਸੰਗ੍ਰਹਿ ਪੈਟਰਨ
#
# ਜਿਵੇਂ ਜਿਵੇਂ ਗੱਲਬਾਤ ਵਧਦੀ ਹੈ, ਅਸੀਂ ਇੱਕ **ਸੰਖੇਪਕ ਸੰਦ** ਦੀ ਵਰਤੋਂ ਕਰ ਸਕਦੇ ਹਾਂ ਜੋ ਸੰਗ੍ਰਹਿਤ ਸੰਦਰਭ ਨੂੰ ਇਕ ਸੰਖੇਪ ਰੂਪ ਵਿੱਚ ਫਰਮਾਉਂਦਾ ਹੈ। ਏਜੰਟ ਇਸ ਸੰਦ ਨੂੰ ਮੁੱਖ ਪਸੰਦਾਂ ਨੂੰ ਦਰਜ ਕਰਨ ਲਈ ਕਾਲ ਕਰਦਾ ਹੈ ਤਾਂ ਜੋ ਜੇ ਪੁਰਾਣੇ ਸੁਨੇਹੇ ਹਟਾਏ ਜਾਣ, ਤਾਂ ਵੀ ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਸੁਰੱਖਿਅਤ ਰਹੇ।
#
# ਇਹ ਪੈਟਰਨ ਹੋਰ ਉੱਚ ਪ੍ਰਤੀਕੂਲ ਇਤਿਹਾਸ ਘਟਾਉਣ ਲਈ ਬੁਨਿਆਦ ਹੈ:
# 1. ਏਜੰਟ ਗੱਲਬਾਤ ਵਿੱਚੋਂ ਮੁੱਖ ਤੱਥ ਪਛਾਣਦਾ ਹੈ
# 2. ਇਹ ਸੰਗ੍ਰਹਿ ਸੰਦ ਨੂੰ ਕਾਲ ਕਰਦਾ ਹੈ ਤਾਂ ਜੋ ਉਹਨਾਂ ਨੂੰ ਸੁਰੱਖਿਅਤ ਕਰ ਸਕੇ
# 3. ਪੁਰਾਣੇ ਸੁਨੇਹੇ ਸੁਰੱਖਿਅਤ ਤੌਰ ਤੇ ਹਟਾਏ ਜਾ ਸਕਦੇ ਹਨ ਕਿਉਂਕਿ ਸਾਰ ਸੰਭਾਲਦਾ ਹੈ ਜੋ ਜਰੂਰੀ ਹੈ
#
# ਹੇਠਾਂ ਅਸੀਂ ਇੱਕ `summarize_preferences` ਸੰਦ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦੇ ਹਾਂ ਜਿਸ ਨੂੰ ਏਜੰਟ ਕਾਲ ਕਰ ਸਕਦਾ ਹੈ ਤਾਂ ਜੋ ਇਸਨੇ ਜੋ ਕੁਝ ਸਿੱਖਿਆ ਹੈ ਉਸ ਦਾ ਇਕ ਸੰਖੇਪ ਸਾਰ ਦਰਜ ਕਰ ਸਕੇ।

# %%
@tool(approval_mode="never_require")
def summarize_preferences(conversation_notes: str) -> str:
    """Summarize accumulated user preferences into a compact format."""
    return f"[SUMMARY] User preferences recorded: {conversation_notes}"


# Create an enhanced agent with the summarization tool
summarizing_agent = await provider.create_agent(
    name="SummarizingTravelAgent",
    instructions="""You are a helpful travel planning assistant that actively manages conversation context.

CONTEXT MANAGEMENT RULES:
1. After gathering several user preferences, call summarize_preferences() to record a compact summary
2. When the user asks you to recall details, reference your recorded summaries
3. Keep responses concise — avoid restating the entire history

PLANNING PROCESS:
1. Gather user preferences (destination, budget, dates, interests)
2. Summarize preferences using the tool
3. Create recommendations based on the summary
4. Update the summary when preferences change""",
    tools=[summarize_preferences],
)

print("🤖 Summarizing travel agent created with context tools")

# %%
# Demonstrate the summarization pattern
summary_session = summarizing_agent.create_session()

# Provide a batch of preferences
response = await summarizing_agent.run(
    "I want to visit Greece. I love seafood, history, and island hopping. "
    "Budget is $4000 for two weeks. Traveling with my partner in June. "
    "Please record these preferences using your summarization tool.",
    session=summary_session,
)
print(f"Agent: {response}\n")

# Ask the agent to use the recorded context
response = await summarizing_agent.run(
    "Now, based on what you've recorded, suggest the top 3 islands we should visit.",
    session=summary_session,
)
print(f"Agent: {response}\n")

# %% [markdown]
# ## ਸੰਖੇਪ
#
# ਇਸ ਪਾਠ ਵਿੱਚ ਤੁਹਾਨੂੰ Microsoft Agent Framework ਦੀ ਵਰਤੋਂ ਕਰਦੇ ਹੋਏ ਲੰਬੇ ਸਮੇਂ ਤੱਕ ਚੱਲ ਰਹੀਆਂ ਏਜੰਟ ਗੱਲਬਾਤਾਂ ਵਿੱਚ ਸੰਦਰਭ ਨੂੰ ਕਿਵੇਂ ਪ੍ਰਬੰਧਿਤ ਕਰਨਾ ਹੈ, ਸਿੱਖਣ ਨੂੰ ਮਿਲਿਆ:
#
# ### ਮੁੱਖ ਧਾਰਣਾ
# - **ਸੰਦਰਭ ਵਿੰਡੋਆਂ ਸਿਮਿਤ ਹੁੰਦੀਆਂ ਹਨ** — ਗੱਲਬਾਤ ਦੇ ਇਤਿਹਾਸ ਵਿੱਚ ਹਰ ਟੋਕਨ ਦੀ ਕੀਮਤ ਹੁੰਦੀ ਹੈ ਅਤੇ ਇਹ ਸੀਮਾ ਵੱਲ ਗਿਣਤੀ ਕਰਦਾ ਹੈ।
# - **ਸੰਖੇਪਕ ਸੰਦ** ਏਜੰਟ ਨੂੰ ਸੰਗ੍ਰਹਿਤ ਸੰਦਰਭ ਨੂੰ ਸੰਕੁਚਿਤ ਸੰਖੇਪ ਵਿਚ ਰੂਪਾਂਤਰਿਤ ਕਰਨ ਦਿੰਦੇ ਹਨ, ਜਿਸ ਨਾਲ ਟੋਕਨ ਦੀ ਵਰਤੋਂ ਘੱਟ ਹੁੰਦੀ ਹੈ ਅਤੇ ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਬਚੀ ਰਹਿੰਦੀ ਹੈ।
# - **ਏਜੰਟ ਸਕ੍ਰੈਚਪैਡ** ਕਦੇ ਵੀ ਖਤਮ ਨਾ ਹੋਣ ਵਾਲੀ ਬਾਹਰੀ ਮੈਮੋਰੀ ਪ੍ਰਦਾਨ ਕਰਦਾ ਹੈ ਜੋ ਕਿਸੇ ਵੀ ਗੱਲਬਾਤ ਕਮੀਆਂ ਤੋਂ ਬਾਅਦ ਜੀਵੰਤ ਰਹਿੰਦੀ ਹੈ।
#
# ### ਤੁਸੀਂ ਕੀ ਬਣਾਇਆ
# - ਇੱਕ **ਸੰਦਰਭ-ਸਜਾਗ ਏਜੰਟ** ਜੋ ਬਹੁ-ਚਰਣ ਗੱਲਬਾਤਾਂ ਵਿੱਚ ਇੱਕਤਾਨਾਂਤਾ ਬਣਾਈ ਰੱਖਦਾ ਹੈ
# - ਇੱਕ **ਸੰਖੇਪਕ ਸੰਦ** (`summarize_preferences`) ਜੋ ਮੁੱਖ ਉਪਭੋਗਤਾ ਵੇਰਵੇ ਸੰਕੁਚਿਤ ਰੂਪ ਵਿੱਚ ਦਰਜ ਕਰਦਾ ਹੈ
# - ਇੱਕ **ਬਹੁ-ਚਰਣ ਗੱਲਬਾਤ** ਜੋ ਸੰਦਰਭ ਬਣਾਈ ਰੱਖਣ ਅਤੇ ਤੇਜ਼ੀ ਨਾਲ ਬਦਲਾਅ ਦੇ ਪ੍ਰਬੰਧਨ ਨੂੰ ਦਰਸਾਉਂਦੀ ਹੈ
#
# ### ਅਸਲੀ ਦੁਨੀਆ ਦੇ ਉਪਯੋਗ
# - **ਗਾਹਕ ਸੇਵਾ ਬੌਟਸ**: ਲੰਬੇ ਸਮੇਂ ਤੱਕ ਸਹਾਇਤਾ ਸੈਸ਼ਨਾਂ ਵਿੱਚ ਪ੍ਰਿਫਰੰਸ ਯਾਦ ਰੱਖਦੇ ਹਨ
# - **ਨਿੱਜੀ ਸਹਾਇਕ**: ਚੱਲ ਰਹੇ ਪ੍ਰੋਜੈਕਟਾਂ ਨੂੰ ਵਿਆਖਿਆ ਕੀਤੇ ਬਿਨਾ ਟ੍ਰੈਕ ਕਰਦੇ ਹਨ
# - **ਸ਼ੈਖੀ ਮਾਹਰ**: ਕਈ ਗੱਲਬਾਤਾਂ ਵਿੱਚ ਵਿਦਿਆਰਥੀ ਦੀ ਤਰੱਕੀ ਜਾਰੀ ਰੱਖਦੇ ਹਨ
#
# ### ਅਗਲੇ ਕਦਮ
# - ਫਾਈਲ-ਆਧਾਰਿਤ ਸਥਿਰਤਾ ਨਾਲ ਪੂਰਾ ਸਕ੍ਰੈਚਪੈਡ ਸੰਦ ਲਾਗੂ ਕਰੋ
# - ਸੰਖੇਪਣ ਦੇ ਬਾਅਦ ਆਟੋਮੈਟਿਕ ਇਤਿਹਾਸ ਕੱਟਣਾ ਸ਼ਾਮਿਲ ਕਰੋ
# - ਸੈਮੈਂਟਿਕ ਮੈਮੋਰੀ ਖੋਜ ਲਈ ਵੇਕਟਰ ਡੇਟਾਬੇਸ ਨਾਲ ਜੋੜੋ
# - ਐਸੇ ਏਜੰਟ ਬਣਾਓ ਜੋ ਦਿਨਾਂ ਬਾਅਦ ਪੂਰੇ ਸੰਦਰਭ ਨਾਲ ਗੱਲਬਾਤ ਮੁੜ ਸ਼ੁਰੂ ਕਰ ਸਕਣ

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ AI ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾ ਲਈ ਯਤਨ ਕਰਦੇ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਵਿੱਚ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਥਿਰਤਾਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਨੂੰ ਇਸ ਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਪ੍ਰਮਾਣਿਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜ਼ਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੀ ਵਰਤੋਂ ਕਾਰਨ ਪੈਦਾਹੈ ਹੋਈ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀ ਜਾਂ ਗਲਤ ਭਾਸ਼ਾ ਦੀ ਜ਼ਿੰਮੇਵਾਰੀ ਨਹੀਂ ਲੈਂਦੇ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
