# %% [markdown]
# # Lektion 08 - Multi-Agent Designmønster

# %% [markdown]
# ## Opsætning

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

# %pip install agent-framework azure-ai-projects azure-identity --quiet

import os
import asyncio

from agent_framework import AgentResponseUpdate, WorkflowBuilder
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %% [markdown]
# ## Hvorfor Multi-Agent Systemer?
#
# Virkelighedens opgaver som rejseplanlægning involverer mange forskellige slags ekspertise — logistik, lokal viden, budgettering og mere. En enkelt agent, der forsøger at håndtere alt, bliver hurtigt uhåndterlig.
#
# Multi-agent systemer løser dette gennem **specialisering**: hver agent fokuserer på et område af ekspertise og leverer resultater af højere kvalitet end en generalist. De forbedrer også **skalerbarheden** — du kan tilføje nye agenter (f.eks. en flyspecialist, en restaurantkritiker) uden at omskrive den eksisterende arbejdsgang. Agenterne sammensættes gennem en struktureret pipeline, hvor de videregiver kontekst fra den ene til den næste.

# %% [markdown]
# ## Oprettelse af specialiserede agenter

# %%
planner_agent = await provider.create_agent(
    name="TravelPlanner",
    instructions="You are a travel planning specialist. Create detailed trip itineraries based on the traveler's preferences. Include daily schedules, must-see attractions, and logistical tips.",
)

concierge_agent = await provider.create_agent(
    name="TravelConcierge",
    instructions="You are a travel concierge who reviews and enhances trip plans. Review the plan for completeness, add local insider tips, suggest restaurants, and identify potential issues. Provide your feedback in a constructive format.",
)

# %% [markdown]
# ## Bygning af en Sekventiel Arbejdsgang
#
# `WorkflowBuilder` lader dig forbinde agenter i en rettet graf. Her opretter vi en simpel to-trins pipeline: **TravelPlanner** udarbejder rejseplanen, og derefter gennemgår og forbedrer **TravelConcierge** den.

# %%
workflow = WorkflowBuilder(start_executor=planner_agent) \
    .add_edge(planner_agent, concierge_agent) \
    .build()

last_author = None
events = workflow.run("Plan a 5-day trip to Paris for a food-loving couple on a $3000 budget.", stream=True)
async for event in events:
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        update = event.data
        author = update.author_name
        if author != last_author:
            if last_author is not None:
                print()
            print(f"\n{'='*50}")
            print(f"🤖 {author}:")
            print(f"{'='*50}")
            last_author = author
        print(update.text, end="", flush=True)

# %% [markdown]
# ## Tilføjelse af flere agenter til arbejdsgangen
#
# En af de største fordele ved multi-agent-mønstret er, hvor nemt det er at udvide. Nedenfor tilføjer vi en **BudgetReviewer** agent, der tjekker planen i forhold til rejsendes budget, markerer punkter, der kan overskride budgettet, og foreslår pengebesparende alternativer. Arbejdsgangen kører nu tre agenter i rækkefølge:
#
# ```
# TravelPlanner → TravelConcierge → BudgetReviewer
# ```

# %%
budget_agent = await provider.create_agent(
    name="BudgetReviewer",
    instructions="You are a budget-conscious travel advisor. Review the proposed trip plan and concierge enhancements against the traveler's stated budget. Estimate costs for flights, hotels, meals, and activities. Flag anything that risks exceeding the budget and suggest cost-saving alternatives while preserving the trip's quality.",
)

extended_workflow = WorkflowBuilder(start_executor=planner_agent) \
    .add_edge(planner_agent, concierge_agent) \
    .add_edge(concierge_agent, budget_agent) \
    .build()

last_author = None
events = extended_workflow.run("Plan a 5-day trip to Paris for a food-loving couple on a $3000 budget.", stream=True)
async for event in events:
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        update = event.data
        author = update.author_name
        if author != last_author:
            if last_author is not None:
                print()
            print(f"\n{'='*50}")
            print(f"🤖 {author}:")
            print(f"{'='*50}")
            last_author = author
        print(update.text, end="", flush=True)

# %% [markdown]
# ## Resumé
#
# I denne lektion lærte du at:
#
# 1. **Oprette specialiserede agenter** — hver med en fokuseret rolle (planlægning, concierge, budgetgennemgang).
# 2. **Koble agenter sammen i en sekventiel arbejdsproces** ved hjælp af `WorkflowBuilder` og `add_edge`.
# 3. **Streame output** fra en multi-agent pipeline og spore, hvilken agent der taler.
# 4. **Udvide en arbejdsproces** ved at tilføje nye agenter til kæden uden at ændre eksisterende.
#
# Designmønstret med flere agenter holder hver agent enkel, mens det producerer rigere, mere grundigt gennemgåede resultater, end en enkelt agent alene kunne opnå.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Ansvarsfraskrivelse**:
# Dette dokument er blevet oversat ved hjælp af AI-oversættelsestjenesten [Co-op Translator](https://github.com/Azure/co-op-translator). Selvom vi bestræber os på nøjagtighed, bedes du være opmærksom på, at automatiske oversættelser kan indeholde fejl eller unøjagtigheder. Det oprindelige dokument på dets modersmål skal betragtes som den autoritative kilde. For kritisk information anbefales professionel menneskelig oversættelse. Vi påtager os intet ansvar for misforståelser eller fejltolkninger, der måtte opstå ved brug af denne oversættelse.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
