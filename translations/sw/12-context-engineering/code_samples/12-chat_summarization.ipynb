# %% [markdown]
# # Somo la 12 - Kupunguza Historia ya Gumzo kwa kutumia Maandishi ya Mwakilishi
#
# Kitabu hiki cha kumbukumbu kinaonyesha jinsi ya kudhibiti muktadha katika mazungumzo marefu kwa kutumia Microsoft Agent Framework. Kadri mazungumzo yanavyozidi, idadi ya tokeni huongezeka — hatimaye ikizidi dirisha la muktadha la mfano. Tunashughulikia hili kwa **mfano wa muhtasari wa muktadha** na **maandishi ya mwakilishi** kwa kumbukumbu endelevu.
#
# ## Uta Jifunza:
# 1. **Kwa Nini Usimamizi wa Muktadha Ni Muhimu**: Kuelewa vizingiti vya tokeni na madirisha ya muktadha
# 2. **Mawakala Wanaojua Muktadha**: Kujenga mawakala wanaosimamia muktadha wa mazungumzo yao
# 3. **Mfano wa Muhtasari wa Muktadha**: Kutumia zana za kufupisha historia ya mazungumzo
# 4. **Maandishi ya Mwakilishi**: Kumbukumbu endelevu inayohifadhiwa hata baada ya kupunguzwa kwa muktadha
#
# ## Sharti:
# - Usanidi wa Azure OpenAI na mazingira yaliyoainishwa
# - Uelewa wa dhana za msingi za mawakala kutoka masomo yaliyopita

# %% [markdown]
# ## Mipangilio

# %%
# %pip install agent-framework azure-ai-projects azure-identity --quiet

# %%
import os
import asyncio
from datetime import datetime
from pathlib import Path

from dotenv import load_dotenv

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
# Load environment variables and create Azure AI Foundry provider
load_dotenv()

provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

print("✅ Azure AI Foundry provider configured")

# %% [markdown]
# ## Kwa Nini Usimamizi wa Muktadha Ni Muhimu
#
# Kila LLM ina **dirisha la muktadha** ambalo lina kikomo — idadi kubwa ya tokeni zinazoweza kushughulikiwa katika ombi moja. Wakati mazungumzo yenye mizunguko mingi yanavyoendelea:
#
# - **Idadi ya tokeni huongezeka kwa mstari** kwa kila ujumbe wa mtumiaji na jibu la msaidizi.
# - **Tokeni za agizo ndizo ghali zaidi** kwa sababu historia yote hurudishwa kila mzunguko.
# - Hatimaye, mazungumzo **huvuka dirisha la muktadha** na mfano hupunguza au kufanya kosa.
#
# ### Mikakati ya Kusimamia Muktadha
#
# | Mkakati | Inavyofanya Kazi | Kifungo cha Matokeo |
# |---|---|---|
# | **Kukata** | Kuacha ujumbe wa zamani zaidi | Huondoa muktadha wa awali |
# | **Muhtasari** | Kukusanya ujumbe wa zamani kuwa muhtasari | Maelezo mengine hayajumuishwa, lakini mambo muhimu hubaki |
# | **Karatasi ya Kuandika / Kumbukumbu ya Nje** | Kuhifadhi mambo muhimu nje ya mazungumzo | Inahitaji mwito wa zana, lakini huishi hata ikiwa kupunguzwa kutatokea |
#
# Katika daftari hili tunachanganya **muhtasari** na **zana ya karatasi ya kuandika** ili wakala aweze kudumisha mfululizo hata kama historia ya mazungumzo itakandamizwa.

# %% [markdown]
# ## Kuunda Wakala Anayeuelewa Muktadha

# %%
agent = await provider.create_agent(
    name="ContextAwareAgent",
    instructions="""You are a helpful travel planning assistant with excellent memory management.
When conversations get long:
1. Summarize previous context into key points
2. Track user preferences mentioned earlier
3. Reference previous decisions without repeating full details
Always maintain continuity while being concise.""",
)

print("🤖 Context-aware travel planning agent created")

# %% [markdown]
# ## Kuiga Mazungumzo Marefu
#
# Hebu tupitie mazungumzo ya mzunguko mwingi kuona jinsi muktadha unavyokusanyika. Wakala anapaswa kuhifadhi maelezo muhimu (mapendeleo, bajeti, tarehe za safari) katika mizunguko yote na kuonyesha mwendelezo.

# %%
session = agent.create_session()

# Turn 1 - Initial preferences
response = await agent.run("I'm planning a trip to Japan. I love sushi, temples, and photography.", session=session)
print(f"Turn 1: {response}\n")

# Turn 2 - More details
response = await agent.run("My budget is $3000 and I'll be traveling solo for 10 days in April.", session=session)
print(f"Turn 2: {response}\n")

# Turn 3 - Test context retention
response = await agent.run("Based on everything I've told you so far, what's the one thing you'd recommend I not miss?", session=session)
print(f"Turn 3: {response}\n")

# %% [markdown]
# Chunguza jinsi wakala anavyohifadhi muktadha kutoka kwa mijadala ya awali — anajua kuhusu Japan, sushi, makaburi, upigaji picha, bajeti ya $3000, kusafiri peke yako, na kipindi cha Aprili. Katika mazungumzo mafupi hii hufanya kazi vizuri, lakini wakati mazungumzo yanapoendelea historia yote inakuwa ghali kutumwa tena.
#
# Tuendelee na mazungumzo yenye mizunguko zaidi ili tuone mkusanyiko wa muktadha:

# %%
# Turn 4 - Expand the conversation
response = await agent.run("What about accommodation? I prefer traditional Japanese inns.", session=session)
print(f"Turn 4: {response}\n")

# Turn 5 - Change of plans
response = await agent.run("Actually, I've changed my mind about the dates. I'll go in October instead for the autumn colors.", session=session)
print(f"Turn 5: {response}\n")

# Turn 6 - Test retention after change
response = await agent.run("Summarize my complete travel plan so far — destination, budget, duration, interests, accommodation, and timing.", session=session)
print(f"Turn 6: {response}\n")

# %% [markdown]
# ## Mfumo wa Muhtasari wa Muktadha
#
# Kadiri mazungumzo yanavyozidi, tunaweza kutumia **zana ya muhtasari** kukusanya muktadha uliokusanywa katika muundo mfupi. Wakala huita zana hii kurekodi mapendeleo muhimu ili hata kama ujumbe wa zamani utatupwa, taarifa muhimu zihifadhiwe.
#
# Mfumo huu ni msingi wa kupunguza historia kwa njia za hali ya juu zaidi:
# 1. Wakala hutambua ukweli muhimu kutoka kwenye mazungumzo
# 2. Huita zana ya muhtasari kuhifadhi taarifa hizo
# 3. Ujumbe wa zamani unaweza kuondolewa salama kwa sababu muhtasari unakamata kinachojali
#
# Hapo chini tunaelezea zana ya `summarize_preferences` ambayo wakala anaweza kuitumia kurekodi muhtasari mfupi wa kile ambacho amejifunza.

# %%
@tool(approval_mode="never_require")
def summarize_preferences(conversation_notes: str) -> str:
    """Summarize accumulated user preferences into a compact format."""
    return f"[SUMMARY] User preferences recorded: {conversation_notes}"


# Create an enhanced agent with the summarization tool
summarizing_agent = await provider.create_agent(
    name="SummarizingTravelAgent",
    instructions="""You are a helpful travel planning assistant that actively manages conversation context.

CONTEXT MANAGEMENT RULES:
1. After gathering several user preferences, call summarize_preferences() to record a compact summary
2. When the user asks you to recall details, reference your recorded summaries
3. Keep responses concise — avoid restating the entire history

PLANNING PROCESS:
1. Gather user preferences (destination, budget, dates, interests)
2. Summarize preferences using the tool
3. Create recommendations based on the summary
4. Update the summary when preferences change""",
    tools=[summarize_preferences],
)

print("🤖 Summarizing travel agent created with context tools")

# %%
# Demonstrate the summarization pattern
summary_session = summarizing_agent.create_session()

# Provide a batch of preferences
response = await summarizing_agent.run(
    "I want to visit Greece. I love seafood, history, and island hopping. "
    "Budget is $4000 for two weeks. Traveling with my partner in June. "
    "Please record these preferences using your summarization tool.",
    session=summary_session,
)
print(f"Agent: {response}\n")

# Ask the agent to use the recorded context
response = await summarizing_agent.run(
    "Now, based on what you've recorded, suggest the top 3 islands we should visit.",
    session=summary_session,
)
print(f"Agent: {response}\n")

# %% [markdown]
# ## Muhtasari
#
# Katika somo hili ulijifunza jinsi ya kusimamia muktadha katika mazungumzo ya mawakala yanayoendelea kwa muda mrefu ukitumia Microsoft Agent Framework:
#
# ### Dhana Muhimu
# - **Dirisha za muktadha ni za kikomo** — kila token katika historia ya mazungumzo huhitaji pesa na kuhesabiwa kuelekea kikomo.
# - **Vifaa vya muhtasari** huruhusu wakala kukusanya muktadha uliokusanywa katika muhtasari mfupi, kupunguza matumizi ya token huku ukihifadhi habari muhimu.
# - **Vitabu vya wakala** hutoa kumbukumbu ya nje inayodumu ambayo huishi baada ya kupunguzwa kwa mazungumzo yoyote.
#
# ### Uliyojenga
# - **Wakala anayeifahamu muktadha** anayehifadhi mfululizo katika mazungumzo yenye mizunguko mingi
# - **Kifaa cha muhtasari** (`summarize_preferences`) kinachorekodi maelezo muhimu ya mtumiaji katika muundo mfupi
# - **Mazungumzo ya mizunguko mingi** yanayoonyesha uhifadhi na usimamizi wa muktadha unaobadilika
#
# ### Matumizi Halisi
# - **Roboti za Huduma kwa Wateja**: Kukumbuka mapendeleo katika vikao virefu vya msaada
# - **Masaada Binafsi**: Kufuatilia miradi inayoendelea bila kurudia kuelezea muktadha
# - **Mwalimu wa Elimu**: Kuhifadhi maendeleo ya mwanafunzi kupitia mwingiliano mingi
#
# ### Hatua Ifuatayo
# - Tekeleza kifaa kamili cha scratchpad chenye uhifadhi wa faili
# - Ongeza ukataji wa historia kwa moja kwa moja baada ya muhtasari
# - Unganisha na hifadhidata za vector kwa ajili ya utafutaji wa kumbukumbu za semantiki
# - Jenga mawakala wanaoweza kuendelea na mazungumzo siku kadhaa baadae wakiwa na muktadha kamili

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kiarifa cha Hukumu**:
# Nakala hii imetafsiriwa kwa kutumia huduma ya kutafsiri kwa AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kuhakikisha usahihi, tafadhali fahamu kuwa tafsiri za kiotomatiki zinaweza kuwa na makosa au kasoro. Nakala ya awali katika lugha yake ya asili inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, inashauriwa kutumia tafsiri ya mtaalamu wa binadamu. Hatuna dhamana kwa mkanganyiko au tafsiri potofu zitokanazo na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
