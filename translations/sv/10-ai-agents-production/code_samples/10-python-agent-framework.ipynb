# %% [markdown]
# # Lektion 10 - AI-agenter i produktion
#
# I den här lektionen kommer du att lära dig **produktionsmönster** för AI-agenter med Microsoft Agent Framework (Python). Vi går igenom:
#
# - **Observerbarhet** — lägga till tidsmätning och loggning av agentinteraktioner
# - **Utvärdering** — använda en utvärderingsagent för att bedöma svarskvaliteten
# - **Kostnadshantering** — strategier för tokenoptimering och modellval
#
# Scenariot är en **reseagent** som hjälper användare att planera resor, med övervakning och utvärdering ovanpå.

# %% [markdown]
# ## Konfiguration

# %%
! pip install agent-framework azure-ai-projects azure-identity -U -q

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os
import asyncio
import time
from typing import Annotated

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
# Create the Azure AI Foundry provider
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %% [markdown]
# ## Produktionsöverväganden
#
# Att flytta AI-agenter från prototyper till produktion kräver noggrann uppmärksamhet på tre pelare:
#
# 1. **Observerbarhet** — Du behöver insyn i vad agenten gör, hur lång tid det tar, och vilka verktyg den anropar. Utan spårning och loggning är det nästan omöjligt att felsöka problem i produktion.
#
# 2. **Utvärdering** — Automatiserade kvalitetskontroller säkerställer att agentens svar förblir korrekta, fullständiga och hjälpsamma över tid. En utvärderingsagent kan poängsätta svar mot definierade kriterier.
#
# 3. **Kostnadshantering** — Tokenanvändning påverkar kostnaden direkt. Strategier som promptoptimering, modellval och caching hjälper till att hålla kostnaderna under kontroll utan att offra kvaliteten.

# %% [markdown]
# ## Bygga en observerbar agent
#
# Vi definierar reseverktyg och omsluter agentanropet med tidtagning så att vi kan övervaka latens. I produktion skulle du integrera med OpenTelemetry eller en liknande spårningsbackend.

# %%
@tool(approval_mode="never_require")
def get_flight_info(destination: Annotated[str, "The destination city"]) -> str:
    """Get flight information for a destination."""
    flights = {
        "Paris": "BA 304, 08:30-11:45, $350",
        "Tokyo": "JL 044, 11:00-07:00+1, $890",
        "Barcelona": "VY 7821, 07:15-10:30, $280",
    }
    return flights.get(destination, f"No flights found to {destination}")


@tool(approval_mode="never_require")
def get_activity_suggestions(destination: Annotated[str, "The destination city"]) -> str:
    """Get activity suggestions for a destination."""
    activities = {
        "Paris": "Louvre Museum, Eiffel Tower, Seine River Cruise, Montmartre walking tour",
        "Tokyo": "Senso-ji Temple, Tsukiji Market tour, Shibuya Crossing, teamLab Borderless",
        "Barcelona": "Sagrada Familia, Park Güell, La Boqueria Market, Gothic Quarter walk",
    }
    return activities.get(destination, f"No activities found for {destination}")

# %%
agent = await provider.create_agent(
    tools=[get_flight_info, get_activity_suggestions],
    name="TravelAgent",
    instructions="You are a helpful travel agent. Use the available tools to help users plan their trips. Provide comprehensive, actionable travel advice.",
)

# Simple observability: track timing
start_time = time.time()
response = await agent.run(
    "I want to plan a day trip in Paris. What flights and activities do you recommend?",
    )
elapsed = time.time() - start_time
print(f"Response ({elapsed:.2f}s):\n{response}")

# %% [markdown]
# ## Utvärderingsmönster
#
# Ett vanligt produktionsmönster är att använda en andra agent som en **utvärderare**.
#
# Utvärderaren bedömer den primära agentens svar utifrån fördefinierade kriterier såsom fullständighet, noggrannhet och hjälpsamhet.
#
# Detta möjliggör:
# - Automatiska kvalitetskontroller innan svar når användarna
# - Upptäckt av regressioner när instruktioner eller modeller ändras
# - Kontinuerlig övervakning av agentens prestanda över tid

# %%
evaluator = await provider.create_agent(
    name="ResponseEvaluator",
    instructions="""You evaluate travel agent responses on these criteria:
1. Completeness (1-5): Did it cover flights AND activities?
2. Accuracy (1-5): Is the information consistent?
3. Helpfulness (1-5): Would a traveler find this actionable?
4. Overall Score (1-5)
Provide scores and a brief explanation for each.""",
)

evaluation = await evaluator.run(f"Evaluate this travel agent response:\n\n{response}")
print(f"Evaluation:\n{evaluation}")

# %% [markdown]
# ## Strategier för kostnadshantering
#
# Att kontrollera kostnader är avgörande för AI-agenter i produktion. Här är viktiga strategier:
#
# | Strategy | Description |
# |---|---|
# | **Promptoptimering** | Håll systeminstruktionerna kortfattade. Ta bort överflödig kontext för att minska antalet inmatningstokens. |
# | **Modellval** | Använd mindre, billigare modeller (t.ex. GPT-4o-mini) för enkla uppgifter som klassificering eller extraktion, och reservera större modeller för komplexare resonemang. |
# | **Cachelagring** | Cachelagra verktygsresultat och frekventa förfrågningar för att undvika onödiga API-anrop. |
# | **Tokenbudgetar** | Sätt gränser för `max_tokens` för att förhindra oväntat långa svar. |
# | **Batchning** | Gruppera flera användarförfrågningar i ett enda API-anrop där det är möjligt. |
#
# I praktiken fungerar en flernivåstrategi bra: skicka enkla förfrågningar till en snabb, billig modell och eskalera endast komplexa förfrågningar till en mer kapabel modell.

# %% [markdown]
# ## Sammanfattning
#
# I den här lektionen lärde du dig hur du:
#
# 1. **Lägga till observerbarhet** i agentinteraktioner med tidsmätning och loggning, vilket lägger grunden för spårning och övervakning.
# 2. **Utvärdera agenters svar** automatiskt med en utvärderingsagent som poängsätter fullständighet, noggrannhet och hjälpsamhet.
# 3. **Hantera kostnader** genom promptoptimering, val av modell, caching och token-budgetar.
#
# Dessa produktionsmönster hjälper till att säkerställa att dina AI-agenter är pålitliga, mätbara och kostnadseffektiva i stor skala.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Ansvarsfriskrivning**:
# Detta dokument har översatts med hjälp av AI-baserade översättningstjänsten [Co-op Translator](https://github.com/Azure/co-op-translator). Även om vi eftersträvar noggrannhet kan automatiska översättningar innehålla fel eller brister. Det ursprungliga dokumentet på dess originalspråk ska betraktas som den auktoritativa källan. För kritisk information rekommenderas professionell mänsklig översättning. Vi ansvarar inte för några missförstånd eller feltolkningar som uppstår till följd av användningen av denna översättning.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
