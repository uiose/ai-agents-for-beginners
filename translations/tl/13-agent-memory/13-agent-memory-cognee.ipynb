# %% [markdown]
# # Aralin 13 - Memorya ng Ahente gamit ang Cognee Knowledge Graphs

# %% [markdown]
# ## Setup
#
# Ipinapakita ng notebook na ito kung paano gumawa ng matalinong **coding assistant** na may permanenteng memorya gamit ang [**Cognee**](https://www.cognee.ai/) knowledge graphs at ang **Microsoft Agent Framework** (MAF).
#
# Ginagawa ng Cognee ang unstructured text na maging isang structured, queryable knowledge graph na suportado ng vector embeddings — na nagbibigay sa iyong agent ng mayamang, relasyon-na-alam na long-term memory.
#
# ### Ano ang Matututunan Mo
# 1. **Gumawa ng Knowledge Graphs**: I-transform ang mga developer profile at best practices sa structured, queryable na kaalaman.
# 2. **I-integrate ang Cognee sa MAF**: Gamitin ang mga `@tool` na function para payagan ang MAF agent na i-query ang Cognee knowledge graph.
# 3. **Session-Aware na Usapan**: Panatilihin ang konteksto sa maraming tanong sa parehong session.
# 4. **Long-Term Memory**: Panatilihin ang mahalagang kaalaman sa pagitan ng mga session at kunin ito sa mga bagong usapan.
#
# ### Kinakailangan
# - Python 3.9+
# - Redis na tumatakbo lokal (`docker run -d -p 6379:6379 redis`) para sa session management
# - Isang LLM API key (hal. OpenAI) — itakda ang `LLM_API_KEY` sa `.env`
# - `CACHING=true` sa `.env` (kailangan para sa Cognee sessions)
# - Isang Azure AI Foundry project na may naka-deploy na chat model
# - `AZURE_AI_PROJECT_ENDPOINT` at `AZURE_AI_MODEL_DEPLOYMENT_NAME` sa `.env`
# - Na-authenticate na Azure CLI (`az login`)

# %%
# %pip install agent-framework azure-ai-projects azure-identity "cognee[redis]==0.4.0" -q

# %%
import os
from pathlib import Path
from typing import Annotated

from dotenv import load_dotenv

load_dotenv()

os.environ["LLM_API_KEY"] = os.getenv("LLM_API_KEY", "")
os.environ["CACHING"] = os.getenv("CACHING", "true")

import cognee
from cognee.modules.search.types import SearchType

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

print(f"Cognee version: {cognee.__version__}")
print(f"CACHING: {os.environ.get('CACHING')}")

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

print("✅ AzureAIProjectAgentProvider created")

# %% [markdown]
# ## Mga Uri ng Memorya ng Ahente
#
# Tinutuklas ng notebook na ito ang parehong tatlong uri ng memorya mula sa pangunahing Lesson 13 notebook, ngunit gumagamit ng Cognee bilang long-term memory backend:
#
# | Uri ng Memorya | Mekanismo | Panahon ng Bisa |
# |---|---|---|
# | **Gumagana** | `agent.create_session()` (MAF) | Isang usapan lang |
# | **Pang-maikling Panahon** | Cognee session cache (Redis) | Isang session lang |
# | **Pang-matagalang Panahon** | Cognee knowledge graph + vectors | Permanenteng |
#
# ### Arkitektura ng Memorya ng Cognee
# ```
# ┌──────────────────────────┐
# │      Raw Data            │  (developer profiles, docs, conversations)
# └───────────┬──────────────┘
#             │  cognee.add() + cognee.cognify()
#             ▼
# ┌──────────────────────────────────────────┐
# │  Knowledge Graph + Vector Embeddings     │
# └───────────┬──────────────────────────────┘
#             │  cognee.search()
#             ▼
# ┌──────────────────┐       ┌────────────────┐
# │  MAF Agent       │──────▶│  @tool funcs   │
# │  (AgentSession)  │       │  wrapping       │
# │                  │       │  cognee.search  │
# └──────────────────┘       └────────────────┘
# ```

# %% [markdown]
# ## Ihanda ang Cognee Storage

# %%
DATA_ROOT = Path('.data_storage').resolve()
SYSTEM_ROOT = Path('.cognee_system').resolve()

DATA_ROOT.mkdir(parents=True, exist_ok=True)
SYSTEM_ROOT.mkdir(parents=True, exist_ok=True)

cognee.config.data_root_directory(str(DATA_ROOT))
cognee.config.system_root_directory(str(SYSTEM_ROOT))

await cognee.prune.prune_data()
await cognee.prune.prune_system(metadata=True)
print("✅ Cognee storage configured and reset")

# %% [markdown]
# ## Part 1 — Pagtatayo ng Knowledge Base
#
# Kami ay kumukuha ng tatlong uri ng data upang lumikha ng isang komprehensibong knowledge base para sa aming coding assistant:
#
# 1. **Developer Profile** — personal na kadalubhasaan at teknikal na background
# 2. **Python Best Practices** — ang Zen ng Python na may mga praktikal na gabay
# 3. **Historical Conversations** — mga nakaraang sesyon ng Q&A sa pagitan ng mga developer at AI assistant

# %%
developer_intro = (
    "Hi, I'm an AI/Backend engineer. "
    "I build FastAPI services with Pydantic, heavy asyncio/aiohttp pipelines, "
    "and production testing via pytest-asyncio. "
    "I've shipped low-latency APIs on AWS, Azure, and GoogleCloud."
)

python_zen_principles = """
# The Zen of Python: Practical Guide

## Key Principles With Guidance

### 1. Beautiful is better than ugly
Prefer descriptive names, clear structure, and consistent formatting.

### 2. Explicit is better than implicit
Be clear about behavior, imports, and types.

### 3. Simple is better than complex
Choose straightforward solutions first.

### 4. Flat is better than nested
Use early returns to reduce indentation.

## Modern Python Tie-ins
- Type hints reinforce explicitness
- Context managers enforce safe resource handling
- Dataclasses improve readability for data containers
"""

human_agent_conversations = """
"conversations": [
    {
      "topic": "async/await patterns",
      "user_query": "I'm building a web scraper that needs to handle thousands of URLs concurrently. What's the best way to structure this with asyncio?",
      "assistant_response": "Use asyncio with aiohttp, a semaphore to cap concurrency, TCPConnector for connection pooling, and context managers for session lifecycle."
    },
    {
      "topic": "dataclass vs pydantic",
      "user_query": "When should I use dataclasses vs Pydantic models?",
      "assistant_response": "For API input/output, prefer Pydantic: runtime validation, type coercion, JSON serialization. Integrates cleanly with FastAPI."
    },
    {
      "topic": "testing patterns",
      "user_query": "What's the best approach for pytest with async functions?",
      "assistant_response": "Use pytest-asyncio, async fixtures, and an isolated test database or mocks to reliably test async code."
    },
    {
      "topic": "error handling and logging",
      "user_query": "What's the best approach for production-ready error management?",
      "assistant_response": "Centralized error handling with custom exceptions, structured logging, and FastAPI middleware."
    }
  ]
"""

print("✅ Data sources prepared")

# %%
await cognee.add(developer_intro, node_set=["developer_data"])
await cognee.add(human_agent_conversations, node_set=["developer_data"])
await cognee.add(python_zen_principles, node_set=["principles_data"])

await cognee.cognify()
print("✅ Knowledge graph built")

# %% [markdown]
# ## I-visualize ang Knowledge Graph
#
# Maaaring magpakita ang Cognee ng isang interactive na HTML na biswal ng mga entidad at mga relasyon na nakuha nito.

# %%
from cognee import visualize_graph

await visualize_graph('./cognee_graph.html')
print("📊 Graph saved to cognee_graph.html — open it in a browser to explore.")

# %% [markdown]
# ## Pagyamanin ang Memorya gamit ang Memify
#
# `memify()` sinusuri ang knowledge graph at bumubuo ng mga intelihenteng patakaran — tinutukoy ang mga pattern, pinakamahusay na mga gawi, at mga ugnayan sa pagitan ng mga konsepto.

# %%
await cognee.memify()
print("✅ Memory enriched with memify")

# %% [markdown]
# ## Bahagi 2 — Ahente ng MAF gamit ang Cognee Tools
#
# Ngayon gagawa tayo ng isang ahente ng MAF na kayang mag-query sa knowledge graph ng Cognee gamit ang mga `@tool` na function. Pinapayagan nito ang ahente na gamitin ang buong kapangyarihan ng graph-aware semantic search habang pinananatili ang konteksto ng pag-uusap sa pamamagitan ng mga session.

# %%
@tool(approval_mode="never_require")
async def search_knowledge(
    query: Annotated[str, "Natural-language question to search the knowledge graph"],
) -> str:
    """Search the Cognee knowledge graph for relevant developer knowledge, best practices, and past conversations."""
    results = await cognee.search(
        query_text=query,
        query_type=SearchType.GRAPH_COMPLETION,
    )
    if not results:
        return "No relevant knowledge found."
    return str(results)


@tool(approval_mode="never_require")
async def search_principles(
    query: Annotated[str, "Question about Python principles or best practices"],
) -> str:
    """Search only the Python principles subset of the knowledge graph."""
    from cognee.modules.engine.models.node_set import NodeSet
    results = await cognee.search(
        query_text=query,
        query_type=SearchType.GRAPH_COMPLETION,
        node_type=NodeSet,
        node_name=["principles_data"],
    )
    if not results:
        return "No relevant principles found."
    return str(results)


print("✅ Cognee tools defined: search_knowledge, search_principles")

# %%
coding_agent = await provider.create_agent(
    name="CodingAssistant",
    instructions=(
        "You are an expert coding assistant with access to a knowledge graph "
        "containing developer profiles, Python best practices, and past conversations.\n\n"
        "WORKFLOW:\n"
        "1. Use search_knowledge() to find relevant information from the full knowledge graph.\n"
        "2. Use search_principles() when the question is specifically about Python best practices.\n"
        "3. Combine retrieved knowledge with your own expertise to give comprehensive answers.\n"
        "4. Reference the developer's known tech stack (FastAPI, asyncio, Pydantic) when relevant."
    ),
)

print("✅ CodingAssistant agent created")

# %% [markdown]
# ## Working Memory with Sessions
#
# Ang `AgentSession` (na nilikha sa pamamagitan ng `agent.create_session()`) ay nagbibigay ng working memory sa loob ng isang session. Maaaring balikan ng ahente ang mga naunang mensahe habang nagtatanong din sa pangmatagalang knowledge graph ng Cognee.

# %%
session = coding_agent.create_session()

response = await coding_agent.run(
    "How does my AsyncWebScraper implementation align with Python's design principles?",
    session=session,
)
print("🤖 Agent:", response)

# %%
response = await coding_agent.run(
    "Based on what you just said, when should I pick dataclasses versus Pydantic for this work?",
    session=session,
)
print("🤖 Agent:", response)
print("\n💡 The agent combined working memory (previous answer) with Cognee's knowledge graph.")

# %% [markdown]
# ## Bagong Sesyon — Nananatili ang Pangmatagalang Memorya
#
# Ang pagsisimula ng bagong sesyon ay naglilinis ng working memory, ngunit ang Cognee knowledge graph ay nananatiling magagamit. Maaaring kunin ng ahente ang parehong pangmatagalang kaalaman sa isang ganap na bagong pag-uusap.

# %%
session_2 = coding_agent.create_session()

response = await coding_agent.run(
    "What logging guidance should I follow for incident reviews?",
    session=session_2,
)
print("🤖 Agent:", response)
print("\n💡 New session, but the agent still has access to the full Cognee knowledge graph.")

# %%
response = await coding_agent.run(
    "How should variables be named according to Python best practices?",
    session=session_2,
)
print("🤖 Agent:", response)

# %% [markdown]
# ## Buod
#
# Sa notebook na ito, gumawa ka ng isang coding assistant na pinagsasama ang **working memory ng MAF** (`agent.create_session()`) at ang **long-term knowledge graph ng Cognee**.
#
# ### Mga Natutunan Mo
# 1. **Pagbuo ng knowledge graph**: Kinakain ng Cognee ang hindi nakaayos na teksto at bumubuo ng graph + vector memory.
# 2. **Pagpapayaman ng graph gamit ang memify**: Nag-derive ng mga katotohanan at mas mayamang relasyon sa ibabaw ng iyong umiiral na graph.
# 3. **Integrasyon ng MAF + Cognee**: Pinapayagan ng mga function na `@tool` ang MAF agent na mag-query sa graph ng Cognee nang natural.
# 4. **Working memory + long-term memory**: Nagbibigay ang `AgentSession` (sa pamamagitan ng `agent.create_session()`) ng konteksto ng session habang nagbibigay ang Cognee ng patuloy na kaalaman.
# 5. **Filtered search gamit ang NodeSets**: Target ang partikular na subset ng knowledge graph (hal. mga prinsipyo lamang).
#
# ### Mga Pangunahing Natutunan
# - **Cognee** ay nagko-convert ng raw na teksto sa istrukturado, relasyon-naalam na memorya — mas makapangyarihan kaysa isang simpleng vector store.
# - Ang mga **`@tool` function** ay tulay sa pagitan ng mga MAF agent at mga panlabas na sistema ng kaalaman nang malinis.
# - Ang **`AgentSession`** (sa pamamagitan ng `agent.create_session()`) ay iniiwan ang konteksto ng bawat pag-uusap na hiwalay sa pangmatagalang kaalaman.
# - Ang parehong knowledge graph ay nagsisilbi sa maraming sessions at agents.
#
# ### Mga Aplikasyong Pang-totoo
# - **Developer copilots**: Code review, pagsusuri ng insidente, architecture assistants
# - **Customer-facing copilots**: Mga support agent sa ibabaw ng product docs, FAQs, at mga tala sa CRM
# - **Internal expert copilots**: Mga katulong sa patakaran, legal, o seguridad na nagrereason sa mga panuntunan
# - **Pinagsamang data layers**: Pagsasama ng istrukturado at hindi istrukturadong data sa isang graph na maaaring i-query
#
# ### Mga Susunod na Hakbang
# - Subukan ang temporal awareness sa Cognee
# - Tukuyin ang OWL ontology para sa domain-specific na kalidad ng graph
# - Magdagdag ng user feedback loops upang pagbutihin ang retrieval sa paglipas ng panahon
# - Mag-scale sa multi-agent na mga sistema na nagbabahagi ng parehong memory layer ng Cognee

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Paunawa**:
# Ang dokumentong ito ay isinalin gamit ang AI translation service na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagamat nagsusumikap kaming maging tumpak, pakatandaan na ang mga awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa kanyang orihinal na wika ang dapat ituring na pinagmulan ng katotohanan. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang hindi pagkakaunawaan o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
