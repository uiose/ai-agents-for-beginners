# %% [markdown]
# # 🐍 使用 Microsoft Agent Framework 的 AI 旅游代理（Python）
#
# ## 📋 场景概述
#
# 本笔记本演示如何使用 Microsoft Agent Framework for Python 构建智能旅游规划代理。该代理利用 GitHub Models 自动生成针对全球随机目的地的个性化一日游行程。
#
# **主要特性：**
# - 🎲 **智能目的地选择**：用于随机选择目的地的自定义工具函数
# - 🗺️ **详细行程生成**：由 AI 驱动的旅游规划，提供本地推荐
# - 🔄 **异步处理**：使用 asyncio 实现高效的 API 通信
# - 🛠️ **工具集成**：演示 AI 代理中的函数调用功能
#
# ## 🏗️ 技术实现
#
# ### 核心组件
# - **Agent Framework**：微软代理编排系统的 Python 实现
# - **GitHub Models API**：通过 GitHub 推理服务访问最先进的语言模型
# - **OpenAI 兼容性**：利用带 GitHub Models 后端的 OpenAI 客户端模式
# - **环境管理**：使用 python-dotenv 进行安全凭据管理
#
# ### 架构流程
# ```python
# User Request → Agent → GitHub Models API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### 关键类与方法
# - `Agent`：主要对话代理编排器
# - `OpenAIChatClient`：GitHub Models API 客户端封装
# - `get_random_destination()`：用于选择目的地的自定义工具函数
# - 环境变量：安全的 API 配置管理
#
# ## ⚙️ 先决条件与设置
#
# **必需依赖项：**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **环境配置（.env 文件）：**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4.1-mini
# ```
#
# **GitHub Models 访问步骤：**
# 1. 注册 GitHub Models 访问权限
# 2. 生成个人访问令牌
# 3. 按上面示例配置环境变量
#
# ## 🚀 使用说明
#
# 依次执行下列代码单元以：
# 1. 导入所需库并加载环境变量
# 2. 定义随机目的地生成工具
# 3. 创建并配置 AI 代理
# 4. 运行旅游规划请求并查看结果
#
# 让我们一起构建智能旅游规划助理吧！🌟

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (1.0.0rc3)
# Requirement already satisfied: typing-extensions in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: python-dotenv<2,>=1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.2.2)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (0.4.15)
# Requirement already satisfied: openai>=1.99.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (2.26.0)
# Requirement already satisfied: azure-identity<2,>=1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.25.2)
# Collecting azure-ai-projects==2.0.0b4 (from agent-framework-core)
#   Using cached azure_ai_projects-2.0.0b4-py3-none-any.whl.metadata (83 kB)
# Requirement already satisfied: mcp<2,>=1.24.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.26.0)
# Requirement already satisfied: packaging>=24.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (26.0)
# Requirement already satisfied: isodate>=0.6.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-ai-projects==2.0.0b4->agent-framework-core) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-ai-projects==2.0.0b4->agent-framework-core) (1.38.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-ai-projects==2.0.0b4->agent-framework-core) (12.28.0)
# Requirement already satisfied: cryptography>=2.5 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.35.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.22)
# Requirement already satisfied: pywin32>=310 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.3.2)
# Requirement already satisfied: starlette>=0.27 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.41.0)
# Requirement already satisfied: websockets>=15.0.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (0.13.0)
# Requirement already satisfied: sniffio in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: idna>=2.8 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: requests>=2.21.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from azure-core>=1.37.0->azure-ai-projects==2.0.0b4->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: certifi in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: colorama in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.1)
# Requirement already satisfied: pycparser in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects==2.0.0b4->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\agentstart\ai-agents-for-beginners\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects==2.0.0b4->agent-framework-core) (2.6.3)
# Using cached azure_ai_projects-2.0.0b4-py3-none-any.whl (231 kB)
# Installing collected packages: azure-ai-projects
#   Attempting uninstall: azure-ai-projects
#     Found existing installation: azure-ai-projects 1.0.0
#     Uninstalling azure-ai-projects-1.0.0:
#       Successfully uninstalled azure-ai-projects-1.0.0
# Successfully installed azure-ai-projects-2.0.0b4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# semantic-kernel 1.40.0 requires azure-ai-projects~=1.0.0b12, but you have azure-ai-projects 2.0.0b4 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# Agent: The main agent class for conversational AI
# tool: Decorator to register functions as agent tools
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import Agent, tool
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
# 在代码中安全地使用敏感信息，而不需要将这些信息硬编码到代码中。
load_dotenv()
# Out:
# True

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
@tool
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL (usually https://models.inference.ai.azure.com)
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"), 
    model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = Agent(
    client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# Your day trip is planned for Sydney, Australia! Here's a suggested itinerary:
#
# ### Morning
# - **Breakfast at The Rocks**: Start your day with a delicious breakfast at one of the cafes in The Rocks area, with a view of Sydney Harbour.
# - **Sydney Opera House**: After breakfast, take a stroll over to the iconic Sydney Opera House. You can take a guided tour to learn about its architecture and history.
#
# ### Midday
# - **Sydney Harbour Bridge**: Walk across the Sydney Harbour Bridge for stunning views of the harbor and city skyline.
# - **Lunch in the Sydney CBD**: Head to the central business district (CBD) for lunch at one of the many restaurants or pubs. Consider trying some local Australian cuisine.
#
# ### Afternoon
# - **Royal Botanic Garden**: After lunch, take a leisurely walk through the Royal Botanic Garden. It's a great place to relax and enjoy nature.
# - **Darling Harbour**: Make your way to Darling Harbour where you can visit attractions like the SEA LIFE Sydney Aquarium or just enjoy the vibrant atmosphere.
#
# ### Evening
# - **Dinner at Darling Harbour**: Choose from a variety of dining options along Darling Harbour for a delightful dinner.
# - **Sunset Views**: After dinner, find a spot along the harbour to watch the sunset – it's a perfect way to end your day in Sydney.
#
# Enjoy your trip! If you need more details or have specific interests, feel free to ask!

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **免责声明**：
# 本文件由人工智能翻译服务 [Co-op Translator](https://github.com/Azure/co-op-translator) 生成。虽然我们力求准确，但请注意，自动翻译可能存在错误或不准确之处。原始语言版本的文件应被视为权威来源。对于关键信息，建议使用专业人工翻译。因使用本翻译内容而产生的任何误解或错误解释，我们不承担任何责任。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
