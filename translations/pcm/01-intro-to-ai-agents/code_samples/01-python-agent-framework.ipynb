# %% [markdown]
# # Lesson 01 - Introduction to AI Agents
#
# Welcome to di first lesson for di **AI Agents for Beginners** course!
#
# An **AI agent** na program wey dey use one big language model (LLM) as im reasoning engine and fit take *actions* for real world — call APIs, ask database, or run code — to achieve one goal for dia user.
#
# For dis notebook you go build your first agent: one **Travel Agent** wey dey recommend vacation destinations. Along di way you go learn how to:
#
# 1. Connect to Azure AI Foundry Agent Service using di **Microsoft Agent Framework**.
# 2. Give di agent one **tool** — one plain Python function wey e fit call.
# 3. Run di agent and check im response.
# 4. Stream di agent's response token-by-token.

# %% [markdown]
# ## Setup
#
# Before you start to run dis notebook, make sure say you get:
#
# 1. **One Azure AI Foundry project** wey get one chat model wey dem don deploy (e.g. `gpt-4o-mini`).
# 2. **You don log in with Azure CLI** — run `az login` for your terminal.
# 3. **Set the correct environment variables:**
#    - `AZURE_AI_PROJECT_ENDPOINT` — your Azure AI Foundry project endpoint.
#    - `AZURE_AI_MODEL_DEPLOYMENT_NAME` — the name wey you give your deployed model.
#
# The cell wey dey below go install the Python packages wey you need.

# %%
# %pip install agent-framework azure-ai-projects azure-identity -q

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os
import asyncio
from typing import Annotated

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %% [markdown]
# ## Creating Your First Agent
#
# An agent need two tins:
#
# - **Instructions** wey dey tell am *who e be* and *how e suppose behave* (a system prompt).
# - **Tools** — Python functions wey dem don put `@tool` on top wey the agent fit call make e gather information or do actions.
#
# Below we define one simple tool wey go return list of popular vacation destinations. The agent go use this tool when person ask for travel recommendations.

# %%
@tool(approval_mode="never_require")
def get_destinations() -> list[str]:
    """Get a list of popular vacation destinations."""
    return [
        "Barcelona",
        "Paris",
        "Berlin",
        "Tokyo",
        "Sydney",
        "New York City",
        "Cairo",
        "Cape Town",
        "Rio de Janeiro",
        "Bali",
    ]

# %%
agent = await provider.create_agent(
    tools=[get_destinations],
    name="TravelAgent",
    instructions=(
        "You are a helpful travel agent. Help users find their perfect vacation "
        "destination based on their preferences. Use the get_destinations tool "
        "to see available destinations."
    ),
)

response = await agent.run(
    "I'm looking for a warm beach destination. What do you recommend?"
)
print(response)

# %% [markdown]
# ## Streaming Responses
#
# For beta wey go make you interact well well, you fit **stream** di agent response. Instead make you dey wait till e finish, di agent go dey give you text small small as e dey create am. Dis one good pass for chat wey you wan show output for real time.

# %%
async for chunk in agent.run(
    "Tell me about Tokyo as a travel destination", stream=True
):
    print(chunk, end="", flush=True)

# %% [markdown]
# ## Summary
#
# For dis lesson, you don learn how to:
#
# - **Create a provider** wey dey connect to Azure AI Foundry Agent Service using `AzureAIProjectAgentProvider`.
# - **Define a tool** with the `@tool` decorator so the agent fit call your Python functions.
# - **Run the agent** with user message and print im response.
# - **Stream responses** for real-time output.
#
# For di next lesson, we go explore agentic frameworks more deep and learn how to give agents beta tools and multi-step reasoning power.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Disclaimer**:
# Dis document don translate wit AI translation service [Co-op Translator](https://github.com/Azure/co-op-translator). Even tho we dey try make am correct, abeg sabi say automated translation fit get errors or wahala. Di original document wey e dey for e own language na di correct one wey you suppose trust. If na important matter, e better make professional human translate am. We no go take responsibility if pipo mis-understand or mis-interpret anything wey come from dis translation.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
